# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re
import numpy as np
from rank_bm25 import BM25Okapi
from sklearn.metrics import precision_score
from collections import Counter

# NLTK downloads
nltk.download('punkt_tab')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Tanvi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Tanvi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tanvi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
try:
    df = pd.read_csv('cleaned_prediction_dates.csv')
except FileNotFoundError:
    print("Error: 'output.csv' not found. Please check the file path.")
    exit(1)

ps = PorterStemmer()
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    if pd.isna(text) or not isinstance(text, str):
        return []
    try:
        tokens = word_tokenize(text.lower())
        processed_tokens = []
        for token in tokens:
            if token in stop_words:
                continue
            if re.match(r'^\d{4}$', token) or re.match(r'^\d+(st|nd|rd|th)$', token):
                processed_tokens.append(token)
            elif token.isalpha():
                processed_tokens.append(ps.stem(token))
        return processed_tokens
    except Exception as e:
        print(f"Error processing text: {text[:50]}... Error: {e}")
        return []

# %%
df['processed_text'] = df['text'].apply(preprocess_text)

# Debug: Inspect data
print("\nData Overview:")
print(df[['topic_id', 'result_id', 'rel']].head(10))
print("\nRel column distribution:")
print(df['rel'].value_counts(dropna=False))
# Out:
# Data Overview:
#                                             topic_id  \
# 0  https://guides.loc.gov/chronicling-america-190...
# 1  https://guides.loc.gov/chronicling-america-190...
# 2  https://guides.loc.gov/chronicling-america-190...
# 3  https://guides.loc.gov/chronicling-america-190...
# 4  https://guides.loc.gov/chronicling-america-190...
# 5  https://guides.loc.gov/chronicling-america-190...
# 6  https://guides.loc.gov/chronicling-america-190...
# 7  https://guides.loc.gov/chronicling-america-190...
# 8  https://guides.loc.gov/chronicling-america-190...
# 9  https://guides.loc.gov/chronicling-america-190...
#
#                                            result_id  rel
# 0  https://www.loc.gov/resource/sn87093407/1904-0...    1
# 1  https://www.loc.gov/resource/sn99063957/1904-0...    1
# 2  https://www.loc.gov/resource/sn85052116/1904-0...    1
# 3  https://www.loc.gov/resource/sn99063957/1904-0...    1
# 4  https://www.loc.gov/resource/sn85066387/1904-0...    1
# 5  https://www.loc.gov/resource/sn83030214/1904-0...    1
# 6  https://www.loc.gov/resource/sn83045366/1904-0...    1
# 7  https://www.loc.gov/resource/sn83045555/1904-0...    0
# 8  https://www.loc.gov/resource/sn83045366/1904-0...    0
# 9  https://www.loc.gov/resource/sn83045366/1904-0...    0
#
# Rel column distribution:
# rel
# 1    364
# 0     75
# Name: count, dtype: int64

# %%
# Organize relevance judgments
rel_judgments = df.groupby('topic_id')[['result_id', 'rel']].apply(
    lambda x: list(zip(x['result_id'].astype(str).str.strip(), x['rel'].astype(int)))
).to_dict()

print("\nRelevance Judgments:")
for topic, judgments in rel_judgments.items():
    relevant_count = sum(1 for _, rel in judgments if rel == 1)
    print(f"Topic: {topic}, Judgments: {len(judgments)}, Relevant: {relevant_count}")
    if judgments:
        print(f"Sample result_ids: {[res_id for res_id, _ in judgments[:2]]}")
# Out:
# Relevance Judgments:
# Topic: https://guides.loc.gov/chronicling-america-16th-amendment, Judgments: 15, Relevant: 10
# Sample result_ids: ['https://www.loc.gov/resource/sn83040198/1909-10-01/ed-1/?sp=5&q=sixteenth+amendment', 'https://www.loc.gov/resource/sn84020558/1912-03-21/ed-1/?sp=1&q=sixteeth+amendment+income+tax']
# Topic: https://guides.loc.gov/chronicling-america-1904-presidential-election, Judgments: 15, Relevant: 9
# Sample result_ids: ['https://www.loc.gov/resource/sn87093407/1904-06-21/ed-1/?sp=1&q=Republican+Convention+Theodore+Roosevelt&st=text&r=-0.06,0.171,0.632,0.632,0', 'https://www.loc.gov/resource/sn99063957/1904-06-21/ed-1/?sp=1&q=Republican+National+Convention+Vice+President+Fairbanks+Roosevelt+Delegations']
# Topic: https://guides.loc.gov/chronicling-america-19th-amendment, Judgments: 12, Relevant: 5
# Sample result_ids: ['https://www.loc.gov/resource/sn85058130/1890-03-27/ed-1/?sp=1&q=Discussing+suffrage', 'https://www.loc.gov/resource/sn85066387/1895-05-21/ed-1/?sp=4&q=Womans+Congress+Pacific+Coast&r=0.239,0.02,0.739,0.346,0']
# Topic: https://guides.loc.gov/chronicling-america-american-female-pilots, Judgments: 11, Relevant: 11
# Sample result_ids: ['https://www.loc.gov/resource/sn88085187/1911-07-24/ed-1/?sp=4&q=aeroplan+aeroplane+aeroplanes+bird+birds+Lady+Mathilde+Moisant', 'https://www.loc.gov/resource/sn85066387/1911-10-17/ed-1/?sp=1&q=Aeroplane+aeroplane+bird+birds+Mathilda+Moissant']
# Topic: https://guides.loc.gov/chronicling-america-babe-ruth, Judgments: 15, Relevant: 11
# Sample result_ids: ['https://chroniclingamerica.loc.gov/lccn/sn86063381/1916-10-09/ed-1/seq-4/#date1=1836&sort=relevance&rows=20&words=Babe+BABE+Ruth+RUTH&searchType=basic&sequence=0&index=5&state=&date2=1922&proxtext=babe+ruth&y=0&x=0&dateFilterType=yearRange&page=10', 'https://chroniclingamerica.loc.gov/lccn/sn83045211/1917-07-02/ed-1/seq-10/#date1=06%2F31%2F1917&index=1&rows=20&searchType=advanced&language=&sequence=0&words=Babe+BASEBALL+George+Herman+punch+punching+RED+Red+red+Ruth+Sox+suspension+Umpire+umpire+umpirical&proxdistance=5&date2=07%2F4%2F1917&ortext=babe+baseball+george+herman+red+sox+ump+umpire+punch+suspension&proxtext=&phrasetext=&andtext=ruth+&dateFilterType=range&page=1']
# Topic: https://guides.loc.gov/chronicling-america-boston-subway, Judgments: 15, Relevant: 11
# Sample result_ids: ['https://www.loc.gov/resource/sn84024441/1897-03-04/ed-1/?sp=5&q=Boston+Dead+dead+explosion+flame+gas+Gas+Subway', 'https://www.loc.gov/resource/sn83030214/1897-09-19/ed-1/?sp=32&q=BOSTON+Boston+BOSTONS+SUBWAY+subway']
# Topic: https://guides.loc.gov/chronicling-america-building-titanic/selected-articles, Judgments: 14, Relevant: 8
# Sample result_ids: ['https://www.loc.gov/resource/sn85042462/1908-04-23/ed-1/?sp=1&q=White+Star+line&r=-0.145,0.964,0.816,0.382,0', 'https://www.loc.gov/resource/sn84026749/1908-10-02/ed-1/?sp=9&q=White+Star+line&r=-1.037,-0.474,3.074,1.44,0']
# Topic: https://guides.loc.gov/chronicling-america-cassius-marcellus-clay-jr, Judgments: 15, Relevant: 14
# Sample result_ids: ['https://www.loc.gov/resource/sn83016804/1960-03-18/ed-1/?sp=7&q=clay%2C+cassius+olympics&st=text&r=0.442,0.737,0.2,0.239,0', 'https://www.loc.gov/resource/sn84021918/1960-09-09/ed-1/?sp=7&q=clay%2C+cassius+olympics&st=text&r=0.289,0.631,0.39,0.466,0']
# Topic: https://guides.loc.gov/chronicling-america-chinese-exclusion-act, Judgments: 12, Relevant: 12
# Sample result_ids: ['www.loc.gov/resource/sn85053040/1882-05-13/ed-1/', 'https://www.loc.gov/resource/sn85066387/1901-11-22/ed-1/']
# Topic: https://guides.loc.gov/chronicling-america-clara-h-barton, Judgments: 15, Relevant: 14
# Sample result_ids: ['https://www.loc.gov/resource/sn83025287/1881-05-22/ed-1/?sp=1&q=Clara+Barton', 'https://www.loc.gov/resource/sn86064205/1887-08-10/ed-1/?sp=1&q=Clara+Barton']
# Topic: https://guides.loc.gov/chronicling-america-darwin-theory-of-evolution, Judgments: 15, Relevant: 12
# Sample result_ids: ['https://www.loc.gov/resource/sn85029094/1863-06-27/ed-1/?sp=1&q=Darwin+Origin+Species', 'https://www.loc.gov/resource/sn83030272/1871-01-21/ed-1/?sp=2&q=Darwin+Darwinism+evolution+Origin+Species+species']
# Topic: https://guides.loc.gov/chronicling-america-early-exercise-tips, Judgments: 14, Relevant: 8
# Sample result_ids: ['https://www.loc.gov/resource/sn90059523/1902-08-31/ed-1/?sp=25', 'https://www.loc.gov/resource/sn83045396/1906-06-24/ed-1/?sp=25']
# Topic: https://guides.loc.gov/chronicling-america-early-women-aviation/selected-articles, Judgments: 15, Relevant: 14
# Sample result_ids: ['https://www.loc.gov/resource/sn85042373/1910-09-01/ed-1/?sp=7&q=Aviation+aviators+women&st=text&r=0.009,0.136,0.872,0.985,0', 'https://www.loc.gov/resource/sn83030214/1910-10-16/ed-1/?sp=56&q=dutrieu+helene&st=text&r=-0.056,-358.174,1.111,717.778,0']
# Topic: https://guides.loc.gov/chronicling-america-eiffel-tower, Judgments: 9, Relevant: 9
# Sample result_ids: ['https://www.loc.gov/resource/sn83025121/1889-04-02/ed-1/?sp=8&q=Eiffel+Tower+France+French+Paris+Worlds+Fair&st=text&r=-0.058,0,1.116,1.41,0', 'https://www.loc.gov/resource/sn91068084/1889-04-26/ed-1/?sp=5&q=Eiffel+Tower+Paris+Exhibition+1000+Feet+High+France+French+Worlds+Fair&st=text&r=-0.335,-0.303,1.669,2.11,0']
# Topic: https://guides.loc.gov/chronicling-america-electric-chair/, Judgments: 12, Relevant: 12
# Sample result_ids: ['https://www.loc.gov/resource/sn85032490/1887-04-17/ed-1/?sp=10&q=Death+Dynamo+Electric+Chair+Capital+Punishment&st=image&r=-0.267,-0.077,1.535,1.535,0', 'https://www.loc.gov/resource/sn86075267/1888-12-13/ed-1/?sp=2&q=Electrical+Electric+Chair+Capital+Punishment+Killing+Electricity+murderers+lightning']
# Topic: https://guides.loc.gov/chronicling-america-ellis-island, Judgments: 13, Relevant: 9
# Sample result_ids: ['https://www.loc.gov/resource/sn85058130/1890-04-01/ed-1/?sp=1&st=text', 'https://chroniclingamerica.loc.gov/lccn/sn83030214/1890-04-06/ed-1/seq-13/ocr/']
# Topic: https://guides.loc.gov/chronicling-america-harry-houdini, Judgments: 15, Relevant: 6
# Sample result_ids: ['https://www.loc.gov/resource/sn84026749/1906-01-07/ed-1/?sp=43', 'https://www.loc.gov/resource/sn84026749/1906-09-29/ed-1/?sp=5']
# Topic: https://guides.loc.gov/chronicling-america-indianapolis-500, Judgments: 15, Relevant: 13
# Sample result_ids: ['https://www.loc.gov/resource/sn83045433/1911-05-31/ed-1/?sp=1&q=500+accident+accidents+automobile+Car+car+cars+crash+crashed+DEATH+death+Indianapolis+injured+Killed+KILLING+RACE+race+racing+speed+Speed&r=-0.573,0.052,2.146,1.026,0', 'https://www.loc.gov/resource/sn83045462/1911-06-04/ed-1/?sp=16&q=500+accidents+automobile+Automobile+AUTOMOBILE+Automobiles+automobiles+Harroun+Indianapolis+INDIANAPOLIS+Mile+miles+motorist+motorists+Race+race+races+racing+Ray+speed+speeding']
# Topic: https://guides.loc.gov/chronicling-america-league-of-nations, Judgments: 13, Relevant: 13
# Sample result_ids: ['https://www.loc.gov/resource/sn83030193/1918-01-08/ed-1/?sp=1&q=Wilson+League+Geneva&st=image&r=-0.918,-0.048,2.835,1.284,0', 'https://www.loc.gov/resource/sn86071134/1919-01-26/ed-1/?sp=1&q=Wilson+League+Geneva']
# Topic: https://guides.loc.gov/chronicling-america-lindbergh-baby-kidnapping, Judgments: 15, Relevant: 13
# Sample result_ids: ['https://chroniclingamerica.loc.gov/lccn/sn82015313/1932-03-02/ed-1/seq-1/#words=25%2C000+Lindbergh+LINDBERGH+Lindberghs+police', 'https://chroniclingamerica.loc.gov/lccn/sn85042243/1932-04-11/ed-1/seq-7/#words=70%2C000+Lindbergh+note+ransom']
# Topic: https://guides.loc.gov/chronicling-america-los-angeles-times-bombing, Judgments: 15, Relevant: 15
# Sample result_ids: ['https://www.loc.gov/resource/sn88084272/1910-10-01/ed-1/?sp=1', 'https://www.loc.gov/resource/sn86072041/1910-10-01/ed-1/?sp=1']
# Topic: https://guides.loc.gov/chronicling-america-marie-curie, Judgments: 15, Relevant: 12
# Sample result_ids: ['https://www.loc.gov/resource/sn88068010/1899-07-28/ed-1/?sp=3&q=Curie+radium', 'https://www.loc.gov/resource/sn83030214/1899-12-17/ed-1/?sp=8&q=Curie+Curies+polonium+Polonium']
# Topic: https://guides.loc.gov/chronicling-america-mothers-day, Judgments: 9, Relevant: 9
# Sample result_ids: ['https://www.loc.gov/resource/sn85066387/1912-05-11/ed-1/?sp=1&q=Miss+Anna+Annie+Jarvis+Mothers%27+Day&st=text&r=-0.294,-0.079,1.589,1.589,0', 'https://www.loc.gov/resource/sn86063381/1912-05-11/ed-1/?sp=2&q=Miss+Anna+Annie+Jarvis+Mothers%27+Day&st=text&r=-0.233,-0.073,1.466,1.466,0']
# Topic: https://guides.loc.gov/chronicling-america-motorcycle-mania, Judgments: 9, Relevant: 9
# Sample result_ids: ['https://www.loc.gov/resource/sn85042591/1869-01-22/ed-1/?sp=1&q=motorcycle+motorcycles+vehicle+street+race&r=0.262,0.46,0.524,0.273,0', 'https://www.loc.gov/resource/sn82015104/1895-11-16/ed-1/?sp=1&q=motorcycle+motorcycles+vehicle+street+race']
# Topic: https://guides.loc.gov/chronicling-america-ouija-board, Judgments: 27, Relevant: 25
# Sample result_ids: ['https://www.loc.gov/resource/sn84028296/1886-04-29/ed-1/?sp=3&q=Ouija+Board+Planchette+Alphabet+Witch+Talking', 'https://www.loc.gov/resource/sn82016373/1890-12-21/ed-1/?sp=2&q=Mysterious+Talking+Wonder+Ouija+Board+Planchette+Alphabet+Witch']
# Topic: https://guides.loc.gov/chronicling-america-ping-pong-craze, Judgments: 10, Relevant: 10
# Sample result_ids: ['https://www.loc.gov/resource/sn83030214/1900-12-23/ed-1/?sp=29&q=TABLE+TENNIS&r=-1.337,-0.016,3.674,1.667,0', 'https://www.loc.gov/resource/sn83030214/1902-01-05/ed-1/?sp=26&q=PING-PONG']
# Topic: https://guides.loc.gov/chronicling-america-prohibition, Judgments: 15, Relevant: 14
# Sample result_ids: ['https://www.loc.gov/resource/sn83030214/1919-10-28/ed-1/?sp=1&q=volstead+act+prohibition&st=text&r=-0.201,-0.07,1.402,1.402,0', 'https://www.loc.gov/resource/sn96060547/1919-01-18/ed-1/?sp=1&q=ratification+prohibition+amendment']
# Topic: https://guides.loc.gov/chronicling-america-roller-skating-craze, Judgments: 15, Relevant: 12
# Sample result_ids: ['https://www.loc.gov/resource/sn86089977/1905-04-01/ed-1/?sp=7&q=Revival+Roller+Skating+Rinks', 'https://www.loc.gov/resource/sn84020274/1905-11-12/ed-1/?sp=13&q=roller+skates+skating+rinks+Young+Enjoys+Fad']
# Topic: https://guides.loc.gov/chronicling-america-statue-of-liberty, Judgments: 13, Relevant: 13
# Sample result_ids: ['https://www.loc.gov/resource/sn84026497/1878-04-17/ed-1/?sp=4&q=Statue+Harbor+Liberty+Lighting+World+Bartholdi', 'https://www.loc.gov/resource/sn82014424/1881-10-11/ed-1/?sp=4&q=COLOSSAL+STATUE+Liberty+Bedloe%27s+Island+Bartholdi']
# Topic: https://guides.loc.gov/chronicling-america-theft-mona-lisa, Judgments: 12, Relevant: 12
# Sample result_ids: ['https://chroniclingamerica.loc.gov/lccn/sn83016810/1910-08-20/ed-1/seq-1/#words=Lisa+Mona', 'https://chroniclingamerica.loc.gov/lccn/sn87078082/1911-09-06/ed-1/seq-6/#words=Lisa+LISA+MONA+Mona']
# Topic: https://guides.loc.gov/chronicling-america-wwi-planes/selected-articles, Judgments: 16, Relevant: 11
# Sample result_ids: ['https://chroniclingamerica.loc.gov/lccn/sn84026749/1917-08-26/ed-1/seq-20/#words=bombs+flying+great+machines+War+war&tab=tab_search', 'https://chroniclingamerica.loc.gov/lccn/sn83030214/1915-03-14/ed-1/seq-39/#words=aeroplane+AEROPLANE+AEROPLANES+aeroplanes+aviator+bomb+Bomb+BOMB+Bombs+bombs+flying+Flying+great+machine+machines+WAR+War+war']
# Topic: https://guides.loc.gov/chronicling-america-yoga, Judgments: 8, Relevant: 8
# Sample result_ids: ['https://chroniclingamerica.loc.gov/lccn/sn84026749/1904-12-18/ed-1/seq-30/#words=Vedanta+Vivekananda+yogis+Swami+yogi+yoga+Yoga', 'https://chroniclingamerica.loc.gov/lccn/sn84026749/1908-05-17/ed-1/seq-37/#words=yoga+Yoga+YOGA+Yogi+Yogis']

# %%
# Initialize BM25
corpus = df['processed_text'].tolist()
result_ids = df['result_id'].astype(str).str.strip().tolist()
bm25 = BM25Okapi(corpus)

def retrieve_bm25(query, top_k=10):
    query_tokens = preprocess_text(query)
    if not query_tokens:
        return []
    scores = bm25.get_scores(query_tokens)
    top_indices = np.argsort(scores)[::-1][:top_k]
    return [
        (result_ids[idx], scores[idx], corpus[idx])
        for idx in top_indices
    ]

def pseudo_relevance_feedback(query, initial_results, top_k=10, feedback_docs=5, terms_to_add=5):
    """
    Apply PRF by extracting terms from top feedback_docs and expanding the query.
    """
    if not initial_results:
        return initial_results
    # Get top feedback_docs
    feedback_indices = [idx for idx, _ in enumerate(initial_results[:feedback_docs])]
    # Collect all tokens from these documents
    feedback_tokens = []
    for _, _, doc_tokens in initial_results[:feedback_docs]:
        feedback_tokens.extend(doc_tokens)
    # Count term frequencies
    term_counts = Counter(feedback_tokens)
    # Exclude original query tokens to avoid redundancy
    query_tokens = preprocess_text(query)
    new_terms = [
        term for term, _ in term_counts.most_common()
        if term not in query_tokens
    ][:terms_to_add]
    # Expand query
    expanded_query = query + ' ' + ' '.join(new_terms)
    print(f"PRF Expanded Query: {expanded_query}")
    # Re-run retrieval
    return retrieve_bm25(expanded_query, top_k)

def expand_query(query, topic_id):
    """
    Explicit query expansion with topic-specific terms.
    """
    expansions = {
        'chinese-exclusion-act': '1882 immigration bill',
        'mona-lisa': 'leonardo painting',
        'statue-of-liberty': '1886 france bartholdi',
        'mothers-day': '1910 wilson',
        'electric-chair': '1890 execution',
        'yoga': 'meditation exercise',
        'motorcycle-mania': 'bike race',
        'female-pilots': 'aviation women',
        'league-of-nations': '1919 wilson treaty',
        'ping-pong-craze': 'table tennis',
        'ouija-board': 'spiritualism board'
    }
    return query + ' ' + expansions.get(topic_id, '')

def evaluate_retrieval(query, retrieved, rel_judgments, k=10):
    topic_id = query.replace(' ', '-')
    relevant = set(res_id for res_id, rel in rel_judgments.get(topic_id, []) if rel == 1)
    print(f"\nTopic: {topic_id}, Relevant result_ids: {relevant}")
    if not relevant:
        print(f"No relevant documents for {topic_id}")
        return 0.0, 0.0
    retrieved_k = [res_id for res_id, _, _ in retrieved[:k]]
    print(f"Retrieved result_ids: {retrieved_k}")
    y_true = [1 if res_id in relevant else 0 for res_id in retrieved_k]
    y_pred = [1] * len(retrieved_k)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = sum(y_true) / len(relevant) if relevant else 0.0
    print(f"Matches: {sum(y_true)} out of {len(relevant)} relevant")
    return precision, recall

# Main evaluation: PRF with and without query expansion
topics = df['topic_id'].unique().tolist()
results = {
    'baseline': {'precisions': [], 'recalls': []},
    'prf': {'precisions': [], 'recalls': []},
    'prf_with_expansion': {'precisions': [], 'recalls': []}
}

for topic in topics:
    query = topic.replace('-', ' ')
    topic_id = topic
    print(f"\n\nEvaluating Topic: {topic}")

    # 1. Baseline BM25
    print("\n--- Baseline BM25 ---")
    baseline_results = retrieve_bm25(query, top_k=10)
    p_base, r_base = evaluate_retrieval(query, baseline_results, rel_judgments, k=10)
    results['baseline']['precisions'].append(p_base)
    results['baseline']['recalls'].append(r_base)
    print(f"Baseline Precision@10: {p_base:.3f}, Recall@10: {r_base:.3f}")

    # 2. PRF without query expansion
    print("\n--- PRF without Query Expansion ---")
    prf_results = pseudo_relevance_feedback(query, baseline_results, top_k=10, feedback_docs=5, terms_to_add=5)
    p_prf, r_prf = evaluate_retrieval(query, prf_results, rel_judgments, k=10)
    results['prf']['precisions'].append(p_prf)
    results['prf']['recalls'].append(r_prf)
    print(f"PRF Precision@10: {p_prf:.3f}, Recall@10: {r_prf:.3f}")

    # 3. PRF with query expansion
    print("\n--- PRF with Query Expansion ---")
    expanded_query = expand_query(query, topic_id)
    print(f"Initial Expanded Query: {expanded_query}")
    initial_results = retrieve_bm25(expanded_query, top_k=10)
    prf_exp_results = pseudo_relevance_feedback(expanded_query, initial_results, top_k=10, feedback_docs=5, terms_to_add=5)
    p_prf_exp, r_prf_exp = evaluate_retrieval(query, prf_exp_results, rel_judgments, k=10)
    results['prf_with_expansion']['precisions'].append(p_prf_exp)
    results['prf_with_expansion']['recalls'].append(r_prf_exp)
    print(f"PRF+Expansion Precision@10: {p_prf_exp:.3f}, Recall@10: {r_prf_exp:.3f}")

# Summarize results
print("\n\nFinal Results:")
for method in results:
    avg_p = np.mean(results[method]['precisions'])
    avg_r = np.mean(results[method]['recalls'])
    print(f"{method.capitalize()} - Avg Precision@10: {avg_p:.3f}, Avg Recall@10: {avg_r:.3f}")
# Out:
# Evaluating Topic: https://guides.loc.gov/chronicling-america-1904-presidential-election
#
# --- Baseline BM25 ---
#
# Topic: https://guides.loc.gov/chronicling-america-1904-presidential-election, Relevant result_ids: {'https://www.loc.gov/resource/sn87093407/1904-06-21/ed-1/?sp=1&q=Republican+Convention+Theodore+Roosevelt&st=text&r=-0.06,0.171,0.632,0.632,0', 'https://www.loc.gov/resource/sn99063957/1904-06-21/ed-1/?sp=1&q=Republican+National+Convention+Vice+President+Fairbanks+Roosevelt+Delegations', 'https://www.loc.gov/resource/sn82014248/1904-09-05/ed-1/?sp=4&q=roosevelt+elected&st=text&r=0.327,0.385,0.41,1.053,0', 'https://www.loc.gov/resource/sn85066387/1904-06-24/ed-1/?sp=1&q=Republican+Convention+Roosevelt+Fairbanks+Running+Mate+President#', 'https://www.loc.gov/resource/sn85052116/1904-06-23/ed-1/?sp=1&q=Republican+Republicans
# Matches: 0 out of 8 relevant
# Baseline Precision@10: 0.000, Recall@10: 0.000
#
# --- PRF without Query Expansion ---
# PRF Expanded Query: https://guides.loc.gov/chronicling america building titanic/selected articles shall state leagu council execut
#
# Topic: https://guides.loc.gov/chronicling-america-building-titanic/selected-articles, Relevant result_ids: {'https://www.loc.gov/resource/sn86086633/1912-04-03/ed-1/?sp=1&q=titanic&r=0.366,0.927,0.6,0.281,0', 'https://chroniclingamerica.loc.gov/lccn/sn82016014/1912-04-15/ed-1/seq-1/#date1=1756&sort=relevance&rows=20&words=ship+Titanic&searchType=basic&sequence=0&index=16&state=&date2=1963&proxtext=Titanic+ship&y=15&x=18&dateFilterType=yearRange&page=2', 'https://www.loc.gov/resource/sn93063916/1910-01-08/ed-1/?sp=1&q=White+Star+Titanic&r=-0.475,0.574,1.91,0.895,0', 'https://www.loc.gov/resource/sn83030214/1910-07-11/ed-1/?sp=3&q=White+Star+Titanic&r=-0.122,0.017,0.649,0.304,0', 'https://www.loc.gov/resource/sn83045462/1911-05-31/ed-1/?sp=5&q=titanic&r=0.677,0.784,0.419,0.197,0', 'https://chroniclingamerica.loc.gov/lccn/sn85053308/1912-04-19/ed-1/seq-3/ocr/', 'https://www.loc.gov/resource/sn83030214/1909-05-30/ed-1/?sp=59&q=White+Star+Titanic&r=-0.124,0.047,1.189,0.557,0', 'https://www.loc.gov/resource/sn83030214/1909-01-03/ed-1/?sp=59&q=White+Star+Titanic&r=-0.04,0.536,0.831,0.389,0'}
# Retrieved result_ids: ['https://www.loc.gov/resource/sn84026749/1919-02-14/ed-1/?sp=1&q=Wilson+League+Geneva', 'https://www.loc.gov/resource/sn88084272/1920-01-16/ed-1/?sp=1&q=Wilson+League+Geneva', 'https://www.loc.gov/resource/sn83045211/1920-01-16/ed-1/?sp=1&q=Wilson+League+Geneva', 'https://www.loc.gov/resource/sn99063957/1910-10-28/ed-1/?sp=1', 'https://www.loc.gov/resource/sn83030214/1920-11-14/ed-1/?sp=1&q=Wilson+League+Geneva', 'https://www.loc.gov/resource/sn86076241/1918-11-29/ed-1/?sp=2&q=league+of+nations', 'https://www.loc.gov/resource/sn84001718/1920-10-29/ed-1/?sp=4&q=league+of+nations&r=-1.137,-0.042,3.274,1.482,0', 'https://www.loc.gov/resource/sn83030214/1919-04-12/ed-1/?sp=1&q=Wilson+League+Geneva', 'https://www.loc.gov/resource/sn95060914/1917-12-21/ed-1/?sp=1&q=PROHIBITION+prohibition+amendment', 'https://www.loc.gov/resource/sn88084272/1917-08-02/ed-1/?sp=12&q=constitutional+amendment']
# Matches: 0 out of 8 relevant
# PRF Precision@10: 0.000, Recall@10: 0.000
#
# --- PRF with Query Expansion ---
# Initial Expanded Query: https://guides.loc.gov/chronicling america building titanic/selected articles
# PRF Expanded Query: https://guides.loc.gov/chronicling america building titanic/selected articles  shall state leagu council execut
LAY+&y=0&x=0&dateFilterType=yearRange&page=1', 'https://www.loc.gov/resource/sn83045462/1963-12-19/ed-1/?sp=71&q=cassius+clay+heavy+weight', 'https://www.loc.gov/resource/sn87065526/1963-07-23/ed-1/?sp=4&q=knockout+cassius+clay', 'https://www.loc.gov/resource/sn83016804/1960-03-18/ed-1/?sp=7&q=clay%2C+cassius+olympics&st=text&r=0.442,0.737,0.2,0.239,0', 'https://chroniclingamerica.loc.gov/lccn/sn84021918/1962-09-14/ed-1/seq-7/#date1=1756&index=15&rows=20&words=Cassius+Clay&searchType=basic&sequence=0&state=&date2=1963&proxtext=CASSIUS+CLAY+&y=0&x=0&dateFilterType=yearRange&page=1']
# Matches: 10 out of 14 relevant
# Baseline Precision@10: 1.000, Recall@10: 0.714
#
# --- PRF without Query Expansion ---
# PRF Expanded Query: https://guides.loc.gov/chronicling america cassius marcellus clay jr heavyweight fight box olymp round
#
# Topic: https://guides.loc.gov/chronicling-america-cassius-marcellus-clay-jr, Relevant result_ids: {'https://www.loc.gov/resource/sn83025327/1963-03-29/ed-1/?sp=16&q=cassius+clay', 'https://www.loc.gov/resource/sn83045462/1963-03-14/ed-1/?sp=33&q=cassius+clay+undefeated', 'https://www.loc.gov/resource/sn83045462/1963-06-19/ed-1/?sp=34&q=cassius+marcellus+clay', 'https://www.loc.gov/resource/sn82001257/1963-03-07/ed-1/?sp=13&q=knockout+cassius+clay&st=text&r=-0.081,0.66,0.501,0.598,0', 'https://chroniclingamerica.loc.gov/lccn/sn84021918/1962-09-14/ed-1/seq-7/#date1=1756&index=15&rows=20&words=Cassius+Clay&searchType=basic&sequence=0&state=&date2=1963&proxtext=CASSIUS+CLAY+&y=0&x=0&dateFilterType=yearRange&page=1', 'https://www.loc.gov/resource/sn83016804/1960-03-18/ed-1/?sp=7&q=clay%2C+cassius+olympics&st=text&r=0.442,0.737,0.2,0.239,0', 'https://chroniclingamerica.loc.gov/lccn/sn83045462/1961-07-16/ed-1/seq-172/#date1=1756&index=1&rows=20&words=Cassius+Clay&searchType=basic&sequence=0&state=&date2=1963&proxtext=CASSIUS+CLAY+&y=0&x=0&dateFilterType=yearRange&page=1', 'https://chroniclingamerica.loc.gov/lccn/sn84020662/1963-07-24/ed-1/seq-3/#date1=1756&index=18&rows=20&words=Cassius+Clay&searchType=basic&sequence=0&state=&date2=1963&proxtext=CASSIUS+CLAY+&y=0&x=0&dateFilterType=yearRange&page=1', 'https://chroniclingamerica.loc.gov/lccn/sn83045462/1963-12-01/ed-1/seq-272/#date1=1756&index=6&rows=20&words=CASSIUS+CLAY&searchType=basic&sequence=0&state=&date2=1963&proxtext=CASSIUS+CLAY+&y=0&x=0&dateFilterType=yearRange&page=1', 'https://www.loc.gov/resource/sn79000083/1963-03-23/ed-1/?sp=7&q=clay%2C+cassius+olympics&r=-0.138,0.178,0.563,0.359,0', 'https://chroniclingamerica.loc.gov/lccn/sn84021918/1960-10-14/ed-1/seq-7/#date1=1756&index=10&rows=20&words=Cassius+Clay&searchType=bas
# Matches: 0 out of 11 relevant
# Baseline Precision@10: 0.000, Recall@10: 0.000
#
# --- PRF without Query Expansion ---
# PRF Expanded Query: https://guides.loc.gov/chronicling america wwi planes/selected articles state shall leagu council execut
#
# Topic: https://guides.loc.gov/chronicling-america-wwi-planes/selected-articles, Relevant result_ids: {'https://chroniclingamerica.loc.gov/lccn/sn83030214/1915-03-14/ed-1/seq-39/#words=aeroplane+AEROPLANE+AEROPLANES+aeroplanes+aviator+bomb+Bomb+BOMB+Bombs+bombs+flying+Flying+great+machine+machines+WAR+War+war', 'https://chroniclingamerica.loc.gov/lccn/sn85042242/1908-09-10/ed-1/seq-1/#words=Aeroplane+flying+machines+Stunts', 'https://chroniclingamerica.loc.gov/lccn/sn86081854/1910-07-15/ed-1/seq-1/#words=Air+AIR+air+aviation+AVIATOR+aviator+Aviator+aviators+exhibitions+FLIER+flying+machine+MACHINE+meet+meeting+meetings+stunt+stunts+Stunts', 'https://chroniclingamerica.loc.gov/lccn/sn83045487/1913-04-29/ed-1/seq-20/#words=Birdmen', 'https://chroniclingamerica.loc.gov/lccn/sn83030272/1914-10-04/ed-1/seq-35/#words=Bleriot', 'https://chroniclingamerica.loc.gov/lccn/sn82016413/1911-03-11/ed-1/seq-11/#words=AEROPLANE+Aeroplane+aeroplane+Aeroplanes+aeroplanes+aeroplaning+aviation+Aviation+AVIATOR+aviator+aviators+AVIATORS+bombs+flying+machines+STUNT+War+war', 'https://chroniclingamerica.loc.gov/lccn/sn84026749/1917-08-26/ed-1/seq-20/#words=bombs+flying+great+machines+War+war&tab=tab_search', 'https://chroniclingamerica.loc.gov/lccn/sn85038615/1911-11-11/ed-1/seq-7/#words=aeroplane+AEROPLANE+aeroplanes+air+event+events+fly+FLYING+flying+machine+Machine+machines+MACHINES+plane+stunt', 'https://chroniclingamerica.loc.gov/lccn/sn96076839/1912-10-19/ed-1/seq-6/#words=aeroplane+aeroplanes+air+event+fly+Flying+flying+machine+Machines+machines+planes+stunt', 'https://chroniclingamerica.loc.gov/lccn/sn83025316/1911-08-27/ed-1/seq-11/#words=aeroplane+aeroplanes+aeroplaning+aviation+aviators+bomb+flying+great+GREAT+International+machines+WAR+war', 'https://chroniclingamerica.loc.gov/lccn/sn83045462/1910-10-30/ed-1/seq-31/#words=aeroplane+aeroplanes+aeroplaning+aviation+bomb+bombs+Bombs+flying+great+machine+war+wars'}
# Retrieved result_ids: ['https://www.loc.gov/resource/sn84026749/1919-02-14/ed-1/?sp=1&q=Wilson+League+Geneva', 'https://www.loc.gov/resource/sn88084272/1920-01-16/ed-1/?sp=1&q=Wilson+League+Geneva', 'https://www.loc.gov/resource/sn83045211/1920-01-16/ed-1/?sp=1&q=Wilson+League+Geneva', 'https://www.loc.gov/resource/sn86076241/1918-11-29/ed-1/?sp=2&q=league+of+nations', 'https://www.loc.gov/resource/sn84001718/1920-10-29/ed-1/?sp=4&q=league+of+nations&r=-1.137,-0.042,3.274,1.482,0', 'https://www.loc.gov/resource/sn83030214/1919-04-12/ed-1/?sp=1&q=Wilson+League+Geneva', 'https://www.loc.gov/resource/sn95060914/1917-12-21/ed-1/?sp=1&q=PROHIBITION+prohibition+amendment', 'https://www.loc.gov/resource/sn99063957/1910-10-28/ed-1/?sp=1', 'https://www.loc.gov/resource/sn88084272/1917-08-02/ed-1/?sp=12&q=constitutional+amendment', 'https://www.loc.gov/resource/sn96060547/1919-01-18/ed-1/?sp=1&q=ratification+prohibition+amendment']
# Matches: 0 out of 11 relevant
# PRF Precision@10: 0.000, Recall@10: 0.000
#
# --- PRF with Query Expansion ---
# Initial Expanded Query: https://guides.loc.gov/chronicling america wwi planes/selected articles
# PRF Expanded Query: https://guides.loc.gov/chronicling america wwi planes/selected articles  state shall leagu council execut
#
# Topic: https://guides.loc.gov/chronicling-america-wwi-planes/selected-articles, Relevant result_ids: {'https://chroniclingamerica.loc.gov/lccn/sn83030214/1915-03-14/ed-1/seq-39/#words=aeroplane+AEROPLANE+AEROPLANES+aeroplanes+aviator+bomb+Bomb+BOMB+Bombs+bombs+flying+Flying+great+machine+machines+WAR+War+war', 'https://chroniclingamerica.loc.gov/lccn/sn85042242/1908-09-10/ed-1/seq-1/#words=Aeroplane+flying+machines+Stunts', 'https://chroniclingamerica.loc.gov/lccn/sn86081854/1910-07-15/ed-1/seq-1/#words=Air+AIR+air+aviation+AVIATOR+aviator+Aviator+aviators+exhibitions+FLIER+flying+machine+MACHINE+meet+meeting+meetings+stunt+stunts+Stunts', 'https://chroniclingamerica.loc.gov/lccn/sn83045487/1913-04-29/ed-1/seq-20/#words=Birdmen', 'https://chroniclingamerica.loc.gov/lccn/sn83030272/1914-10-04/ed-1/seq-35/#words=Bleriot', 'https://chroniclingamerica.loc.gov/lccn/sn82016413/1911-03-11/ed-1/seq-11/#words=AEROPLANE+Aeroplane+aeroplane+Aeroplanes+aeroplanes+aeroplaning+aviation+Aviation+AVIATOR+aviator+aviators+AVIATORS+bombs+flying+machines+STUNT+War+war', 'https://chroniclingamerica.loc.gov/lccn/sn84026749/1917-08-26/ed-1/seq-20/#words=bombs+flying+great+machines+War+war&tab=tab_search', 'https://chroniclingamerica.loc.gov/lccn/sn85038615/1911-11-11/ed-1/seq-7/#words=aeroplane+AEROPLANE+aeroplanes+air+event+events+fly+FLYING+flying+machine+Machine+machines+MACHINES+plane+stunt', 'https://chroniclingamerica.loc.gov/lccn/sn96076839/1912-10-19/ed-1/seq-6/#words=aeroplane+aeroplanes+air+event+fly+Flying+flying+machine+Machines+machines+planes+stunt', 'https://chroniclingamerica.loc.gov/lccn/sn83025316/1911-08-27/ed-1/seq-11/#words=aeroplane+aeroplanes+aeroplaning+aviation+aviators+bomb+flying+great+GREAT+International+machines+WAR+war', 'https://chroniclingamerica.loc.gov/lccn/sn83045462/1910-10-30/ed-1/seq-31/#words=aeroplane+aeroplanes+aeroplaning+aviation+bomb+bombs+Bombs+flying+great+machine+war+wars'}
GA+Yogi+Yogis', 'https://www.loc.gov/resource/sn83045389/1915-02-07/ed-1/?sp=15&q=Indianapolis+500+mile+Race', 'https://www.loc.gov/resource/sn83030214/1899-12-17/ed-1/?sp=8&q=Curie+Curies+polonium+Polonium', 'https://www.loc.gov/resource/sn84026497/1878-04-17/ed-1/?sp=4&q=Statue+Harbor+Liberty+Lighting+World+Bartholdi']
# Matches: 6 out of 8 relevant
# PRF+Expansion Precision@10: 0.600, Recall@10: 0.750
#
#
# Final Results:
# Baseline - Avg Precision@10: 0.694, Avg Recall@10: 0.616
# Prf - Avg Precision@10: 0.703, Avg Recall@10: 0.624
# Prf_with_expansion - Avg Precision@10: 0.703, Avg Recall@10: 0.624

# %%
output = []
for topic in topics:
    query = topic.replace('-', ' ')
    for method in ['baseline', 'prf', 'prf_with_expansion']:
        if method == 'baseline':
            res = retrieve_bm25(query, top_k=10)
        elif method == 'prf':
            res = pseudo_relevance_feedback(query, retrieve_bm25(query, top_k=10), top_k=10)
        else:
            expanded_query = expand_query(query, topic)
            res = pseudo_relevance_feedback(expanded_query, retrieve_bm25(expanded_query, top_k=10), top_k=10)
        for result_id, score, _ in res:
            output.append({
                'topic_id': topic,
                'method': method,
                'result_id': result_id,
                'score': score
            })
output_df = pd.DataFrame(output)
output_df.to_csv('retrieval_results_prf.csv', index=False)
print("\nResults saved to 'retrieval_results_prf.csv'")
# Out:
# PRF Expanded Query: https://guides.loc.gov/chronicling america 1904 presidential election state amend nation june vote
# PRF Expanded Query: https://guides.loc.gov/chronicling america 1904 presidential election  state amend nation june vote
# PRF Expanded Query: https://guides.loc.gov/chronicling america early women aviation/selected articles shall leagu state council execut
# PRF Expanded Query: https://guides.loc.gov/chronicling america early women aviation/selected articles  shall leagu state council execut
# PRF Expanded Query: https://guides.loc.gov/chronicling america clara h barton work cross war red ot
# PRF Expanded Query: https://guides.loc.gov/chronicling america clara h barton  work cross war red ot
# PRF Expanded Query: https://guides.loc.gov/chronicling america boston subway tho street tunnel car station
# PRF Expanded Query: https://guides.loc.gov/chronicling america boston subway  tho street tunnel car station
# PRF Expanded Query: https://guides.loc.gov/chronicling america building titanic/selected articles shall state leagu council execut
# PRF Expanded Query: https://guides.loc.gov/chronicling america building titanic/selected articles  shall state leagu council execut
# PRF Expanded Query: https://guides.loc.gov/chronicling america cassius marcellus clay jr heavyweight fight box olymp round
# PRF Expanded Query: https://guides.loc.gov/chronicling america cassius marcellus clay jr  heavyweight fight box olymp round
# PRF Expanded Query: https://guides.loc.gov/chronicling america chinese exclusion act peopl labor petit question noe
# PRF Expanded Query: https://guides.loc.gov/chronicling america chinese exclusion act  peopl labor petit question noe
# PRF Expanded Query: https://guides.loc.gov/chronicling america indianapolis 500 race car driver first event
# PRF Expanded Query: https://guides.loc.gov/chronicling america indianapolis 500  race car driver first event
# PRF Expanded Query: https://guides.loc.gov/chronicling america babe ruth team basebal player world game
# PRF Expanded Query: https://guides.loc.gov/chronicling america babe ruth  team basebal player world game
# PRF Expanded Query: https://guides.loc.gov/chronicling america marie curie radium mme madam woman pari
# PRF Expanded Query: https://guides.loc.gov/chronicling america marie curie  radium mme madam woman pari
# PRF Expanded Query: https://guides.loc.gov/chronicling america darwin theory of evolution tho natur select speci anim
# PRF Expanded Query: https://guides.loc.gov/chronicling america darwin theory of evolution  tho natur select speci anim
# PRF Expanded Query: https://guides.loc.gov/chronicling america eiffel tower feet pari structur year great
# PRF Expanded Query: https://guides.loc.gov/chronicling america eiffel tower  feet pari structur year great
# PRF Expanded Query: https://guides.loc.gov/chronicling america electric chair/ tho death would prison bo
# PRF Expanded Query: https://guides.loc.gov/chronicling america electric chair/  tho death would prison bo
# PRF Expanded Query: https://guides.loc.gov/chronicling america ellis island immigr build tho one land
# PRF Expanded Query: https://guides.loc.gov/chronicling america ellis island  immigr build tho one land
# PRF Expanded Query: https://guides.loc.gov/chronicling america american female pilots th aviat woman flight fli
# PRF Expanded Query: https://guides.loc.gov/chronicling america american female pilots  th aviat woman flight fli
# PRF Expanded Query: https://guides.loc.gov/chronicling america harry houdini box water hand minut handcuff
# PRF Expanded Query: https://guides.loc.gov/chronicling america harry houdini  box water hand minut handcuff
# PRF Expanded Query: https://guides.loc.gov/chronicling america league of nations shall council state execut world
# PRF Expanded Query: https://guides.loc.gov/chronicling america league of nations  shall council state execut world
# PRF Expanded Query: https://guides.loc.gov/chronicling america lindbergh baby kidnapping polic child home new said
# PRF Expanded Query: https://guides.loc.gov/chronicling america lindbergh baby kidnapping  polic child home new said
# PRF Expanded Query: https://guides.loc.gov/chronicling america los angeles times bombing mcnamara oti labor crime nnd
# PRF Expanded Query: https://guides.loc.gov/chronicling america los angeles times bombing  mcnamara oti labor crime nnd
# PRF Expanded Query: https://guides.loc.gov/chronicling america theft mona lisa paint louvr pictur one italian
# PRF Expanded Query: https://guides.loc.gov/chronicling america theft mona lisa  paint louvr pictur one italian
# PRF Expanded Query: https://guides.loc.gov/chronicling america mothers day tho state may celebr one
# PRF Expanded Query: https://guides.loc.gov/chronicling america mothers day  tho state may celebr one
# PRF Expanded Query: https://guides.loc.gov/chronicling america motorcycle mania race one hors run mile
# PRF Expanded Query: https://guides.loc.gov/chronicling america motorcycle mania  race one hors run mile
# PRF Expanded Query: https://guides.loc.gov/chronicling america ouija board yost walter form suit spiritualist
# PRF Expanded Query: https://guides.loc.gov/chronicling america ouija board  yost walter form suit spiritualist
# PRF Expanded Query: https://guides.loc.gov/chronicling america ping pong craze tabl club pingpong game play
# PRF Expanded Query: https://guides.loc.gov/chronicling america ping pong craze  tabl club pingpong game play
# PRF Expanded Query: https://guides.loc.gov/chronicling america prohibition tho enforc page new law
# PRF Expanded Query: https://guides.loc.gov/chronicling america prohibition  tho enforc page new law
# PRF Expanded Query: https://guides.loc.gov/chronicling america roller skating craze tho one rink make chinaman
# PRF Expanded Query: https://guides.loc.gov/chronicling america roller skating craze  tho one rink make chinaman
# PRF Expanded Query: https://guides.loc.gov/chronicling america 16th amendment state senat ratifi hous vote
# PRF Expanded Query: https://guides.loc.gov/chronicling america 16th amendment  state senat ratifi hous vote
# PRF Expanded Query: https://guides.loc.gov/chronicling america statue of liberty bartholdi french tho franc new
# PRF Expanded Query: https://guides.loc.gov/chronicling america statue of liberty  bartholdi french tho franc new
# PRF Expanded Query: https://guides.loc.gov/chronicling america early exercise tips arm back shoulder bodi one
# PRF Expanded Query: https://guides.loc.gov/chronicling america early exercise tips  arm back shoulder bodi one
# PRF Expanded Query: https://guides.loc.gov/chronicling america 19th amendment state senat ratifi hous vote
# PRF Expanded Query: https://guides.loc.gov/chronicling america 19th amendment  state senat ratifi hous vote
# PRF Expanded Query: https://guides.loc.gov/chronicling america wwi planes/selected articles state shall leagu council execut
# PRF Expanded Query: https://guides.loc.gov/chronicling america wwi planes/selected articles  state shall leagu council execut
# PRF Expanded Query: https://guides.loc.gov/chronicling america yoga la el de mind power
# PRF Expanded Query: https://guides.loc.gov/chronicling america yoga  la el de mind power
#
# Results saved to 'retrieval_results_prf.csv'

# %%
df
# Out:
#                                               topic_id  \
# 0    https://guides.loc.gov/chronicling-america-190...
# 1    https://guides.loc.gov/chronicling-america-190...
# 2    https://guides.loc.gov/chronicling-america-190...
# 3    https://guides.loc.gov/chronicling-america-190...
# 4    https://guides.loc.gov/chronicling-america-190...
# ..                                                 ...
# 434    https://guides.loc.gov/chronicling-america-yoga
# 435    https://guides.loc.gov/chronicling-america-yoga
# 436    https://guides.loc.gov/chronicling-america-yoga
# 437    https://guides.loc.gov/chronicling-america-yoga
# 438    https://guides.loc.gov/chronicling-america-yoga
#
#                                              result_id  rel  \
# 0    https://www.loc.gov/resource/sn87093407/1904-0...    1
# 1    https://www.loc.gov/resource/sn99063957/1904-0...    1
# 2    https://www.loc.gov/resource/sn85052116/1904-0...    1
# 3    https://www.loc.gov/resource/sn99063957/1904-0...    1
# 4    https://www.loc.gov/resource/sn85066387/1904-0...    1
# ..                                                 ...  ...
# 434  https://chroniclingamerica.loc.gov/lccn/sn8506...    1
# 435  https://www.loc.gov/resource/sn83016209/1961-0...    1
# 436  https://www.loc.gov/resource/sn86002403/1951-1...    1
# 437  https://www.loc.gov/resource/sn82001257/1961-0...    1
# 438  https://www.loc.gov/resource/sn88063294/1945-0...    1
#
#                                                   text  \
# 0    REPUBLICAN CONVENTION GETS DOWN TO BUSINESS O....
# 1    NATIONAL REPUBLICAN CONVENTION Fairbanks for V...
# 2    Convention Hall Chicago Juno 23 This the third...
# 3    ROOSEVELT AND FAIRBANKS Republican National Co...
# 4    ROOSEVELT WILL LEAD PARTY TO VICTORY; HIS RUNN...
# ..                                                 ...
# 434  A PAGE HOW YOUNG GIRLS STUDY THE FOR HINDOO ME...
# 435  POsition Is Everything in Life to Yogi Practit...
# 436  ¿Qué Es El Yoga? Yoga es una palabra sánscrita...
# 437  Con la Práctica del Yoga se Puede Vivir Muchos...
# 438  Love Tangles Too, Too Solid Even for Yoga Mrs....
#
#                                                   time        date  \
# 0    June 21, 1904 : The Republican National Conven...  21-06-1904
# 1    June 21, 1904 : The Republican National Conven...  21-06-1904
# 2    June 21, 1904 : The Republican National Conven...  21-06-1904
# 3    June 23, 1904 : Theodore Roosevelt is nominate...  23-06-1904
# 4    June 23, 1904 : Charles Fairbanks is named as ...  23-06-1904
# ..                                                 ...         ...
# 434                                            MISSING         NaN
# 435                                            MISSING         NaN
# 436                                            MISSING         NaN
# 437                                            MISSING         NaN
# 438                                            MISSING         NaN
#
#                                                  event  predicted_Date  \
# 0    The Republican National Convention begins in C...             NaN
# 1    The Republican National Convention begins in C...             NaN
# 2    The Republican National Convention begins in C...             NaN
# 3    Theodore Roosevelt is nominated for the Presid...             NaN
# 4    Charles Fairbanks is named as his Vice Preside...             NaN
# ..                                                 ...             ...
# 434                                                NaN             NaN
# 435                                                NaN             NaN
# 436                                                NaN             NaN
# 437                                                NaN             NaN
# 438                                                NaN             NaN
#
#                                         predicted_date      extracted_dates  \
# 0    The exact date mentioned in the text is:\r\n\r...          ['June 11']
# 1                                              June 21          ['June 21']
# 2                                        June 23, 1904  ['June 23', '1904']
# 3                                        June 20, 1904  ['June 20', '1904']
# 4    The exact date of the major event being discus...          ['June 13']
# ..                                                 ...                  ...
# 434                                 No timeline found.                   []
# 435                                         2000 years             ['2000']
# 436                                 No timeline found.                   []
# 437                                         2,000 años                   []
# 438                                               1940             ['1940']
#
#                                         processed_text
# 0    [republican, convent, get, busi, leader, organ...
# 1    [nation, republican, convent, fairbank, vice, ...
# 2    [convent, hall, chicago, juno, third, sad, hut...
# 3    [roosevelt, fairbank, republican, nation, conv...
# 4    [roosevelt, lead, parti, victori, run, mate, p...
# ..                                                 ...
# 434  [page, young, girl, studi, hindoo, method, res...
# 435  [posit, everyth, life, yogi, practition, tiwar...
# 436  [es, el, yoga, yoga, es, una, palabra, sánscri...
# 437  [con, la, práctica, del, yoga, se, pued, vivir...
# 438  [love, tangl, solid, even, yoga, florenc, stre...
#
# [439 rows x 11 columns]

# %%
import ast

# %%
ast.literal_eval(df['extracted_dates'][0])
# Out:
# ['June 11']

# %%
time = []
for i in range(0, len(output_df)):
    topic_id = output_df['topic_id'][i]
    cur_time = ""
    for j in range(0, len(df)):
        if (topic_id) == df['topic_id'][j]:
            cur_time_list = ast.literal_eval(df['extracted_dates'][j])
            if (cur_time_list != []):
                cur_time = cur_time_list[0]
            else:
                cur_time = "No timeline found"
            break
    time.append(cur_time)

# %%
query
# Out:
# 'https://guides.loc.gov/chronicling america yoga'

# %%
output_df['predicted_time'] = time

# %%
categories = output_df['predicted_time'].unique()

# %%
output_df_sorted = output_df.sort_values(by = 'score', ascending = False).reset_index().drop('index', axis = 1)

# %%
output_df_sorted
# Out:
#                                               topic_id              method  \
# 0    https://guides.loc.gov/chronicling-america-pin...                 prf
# 1    https://guides.loc.gov/chronicling-america-pin...  prf_with_expansion
# 2    https://guides.loc.gov/chronicling-america-the...  prf_with_expansion
# 3    https://guides.loc.gov/chronicling-america-the...                 prf
# 4    https://guides.loc.gov/chronicling-america-the...  prf_with_expansion
# ..                                                 ...                 ...
# 955  https://guides.loc.gov/chronicling-america-wwi...            baseline
# 956  https://guides.loc.gov/chronicling-america-wwi...            baseline
# 957  https://guides.loc.gov/chronicling-america-har...            baseline
# 958    https://guides.loc.gov/chronicling-america-yoga            baseline
# 959    https://guides.loc.gov/chronicling-america-yoga            baseline
#
#                                              result_id      score  \
# 0    https://www.loc.gov/resource/sn82016357/1902-0...  47.641696
# 1    https://www.loc.gov/resource/sn82016357/1902-0...  47.641696
# 2    https://chroniclingamerica.loc.gov/lccn/sn8304...  42.867909
# 3    https://chroniclingamerica.loc.gov/lccn/sn8304...  42.867909
# 4    https://chroniclingamerica.loc.gov/lccn/sn9902...  42.256602
# ..                                                 ...        ...
# 955  https://www.loc.gov/resource/sn86099906/1903-0...   4.116640
# 956  https://www.loc.gov/resource/sn88085620/1910-1...   3.862804
# 957  https://www.loc.gov/resource/sn82014424/1881-1...   3.502106
# 958  https://www.loc.gov/resource/sn82014424/1881-1...   3.502106
# 959  https://www.loc.gov/resource/sn84026497/1878-0...   3.287218
#
#         predicted_time
# 0    No timeline found
# 1    No timeline found
# 2    No timeline found
# 3    No timeline found
# 4    No timeline found
# ..                 ...
# 955  No timeline found
# 956  No timeline found
# 957  No timeline found
# 958  No timeline found
# 959  No timeline found
#
# [960 rows x 5 columns]

# %%
categories_dict = {}
for i in (output_df_sorted['predicted_time'].value_counts()).keys():
    categories_dict[i] = 0

# %%
results = categories_dict.copy()
for i in range(0, len(output_df_sorted)):
    if output_df_sorted['predicted_time'][i] == "No timeline found":
        time = "No timeline found" 
    else:
        time = (output_df_sorted['predicted_time'][i])  
    time = str(time)
    if (categories_dict[time] < 5): #### THIS CAN BE CHANGED TO REFLECT THE NUMBER OF RESULTS WE WANT TO SEE
        if (results[time] == 0):
            results[time] = [output_df_sorted['result_id'][i]]
        else:
            results[time].append(output_df_sorted['result_id'][i])
        categories_dict[time] += 1

# %%
categories_dict
# Out:
# {'No timeline found': 5,
#  '1902': 5,
#  'June 21': 5,
#  '1793': 5,
#  '1334': 5,
#  'July 1882': 5,
#  '1870': 5,
#  '1932': 5,
#  '1876': 5,
#  '1879': 5,
#  '1917': 5,
#  'March 31': 5,
#  'June 11': 5,
#  'May 30': 5,
#  '1904': 5}

# %%
results
# Out:
# {'No timeline found': ['https://www.loc.gov/resource/sn82016357/1902-05-03/ed-1/?sp=7&q=PING-PONG+ping+pong+craze&r=-1.345,-0.063,3.69,1.674,0',
#   'https://www.loc.gov/resource/sn82016357/1902-05-03/ed-1/?sp=7&q=PING-PONG+ping+pong+craze&r=-1.345,-0.063,3.69,1.674,0',
#   'https://chroniclingamerica.loc.gov/lccn/sn83045462/1914-03-20/ed-1/seq-10/#words=LISA+Lisa+Mona+MONA',
#   'https://chroniclingamerica.loc.gov/lccn/sn83045462/1914-03-20/ed-1/seq-10/#words=LISA+Lisa+Mona+MONA',
#   'https://chroniclingamerica.loc.gov/lccn/sn99021999/1913-12-14/ed-1/seq-4/#words=Lisa+Mona'],
#  '1902': ['https://www.loc.gov/resource/sn86063381/1921-04-05/ed-1/?sp=2&q=Curie+Marie+radium',
#   'https://www.loc.gov/resource/sn86063381/1921-04-05/ed-1/?sp=2&q=Curie+Marie+radium',
#   'https://www.loc.gov/resource/sn84026749/1921-03-13/ed-1/?sp=1&q=Curie+Marie',
#   'https://www.loc.gov/resource/sn84026749/1921-03-13/ed-1/?sp=1&q=Curie+Marie',
#   'https://www.loc.gov/resource/sn85066387/1911-11-08/ed-1/?sp=1&q=Curie+Marie+NOBEL+Nobel+prize+Prize+Prizes+prizes'],
#  'June 21': ['https://www.loc.gov/resource/sn84021918/1960-09-09/ed-1/?sp=7&q=clay%2C+cassius+olympics&st=text&r=0.289,0.631,0.39,0.466,0',
#   'https://www.loc.gov/resource/sn84021918/1960-09-09/ed-1/?sp=7&q=clay%2C+cassius+olympics&st=text&r=0.289,0.631,0.39,0.466,0',
#   'https://www.loc.gov/resource/sn83045462/1963-06-19/ed-1/?sp=34&q=cassius+marcellus+clay',
#   'https://www.loc.gov/resource/sn83045462/1963-06-19/ed-1/?sp=34&q=cassius+marcellus+clay',
#   'https://www.loc.gov/resource/sn79000083/1963-03-23/ed-1/?sp=7&q=clay%2C+cassius+olympics&r=-0.138,0.178,0.563,0.359,0'],
#  '1793': ['https://www.loc.gov/resource/sn84031492/1873-07-27/ed-1/?sp=8&q=Charles+Darwin+Natural+Selection+evolution',
#   'https://www.loc.gov/resource/sn84031492/1873-07-27/ed-1/?sp=8&q=Charles+Darwin+Natural+Selection+evolution',
#   'https://www.loc.gov/resource/sn83045462/1882-04-22/ed-1/?sp=6&q=Darwin+Darwinism+origin+species',
#   'https://www.loc.gov/resource/sn83045462/1882-04-22/ed-1/?sp=6&q=Darwin+Darwinism+origin+species',
#   'https://www.loc.gov/resource/sn84026844/1874-02-06/ed-1/?sp=3&q=Darwin+Darwinism+origin+species'],
#  '1334': ['https://www.loc.gov/resource/sn86063381/1920-02-24/ed-1/?sp=1&q=Revelation+Lawsuit+Albert+Yost+Ouija+Board+Planchette+Alphabet+Witch',
#   'https://www.loc.gov/resource/sn86063381/1920-02-24/ed-1/?sp=1',
#   'https://www.loc.gov/resource/sn86063381/1920-02-24/ed-1/?sp=1&q=Revelation+Lawsuit+Albert+Yost+Ouija+Board+Planchette+Alphabet+Witch',
#   'https://www.loc.gov/resource/sn86063381/1920-02-24/ed-1/?sp=1',
#   'https://chroniclingamerica.loc.gov/lccn/sn93061777/1920-07-15/ed-1/seq-2'],
#  'July 1882': ['https://www.loc.gov/resource/sn86076200/1901-08-03/ed-1/',
#   'https://www.loc.gov/resource/sn86076200/1901-08-03/ed-1/',
#   'https://www.loc.gov/resource/sn85066387/1901-11-26/ed-1/',
#   'https://www.loc.gov/resource/sn85066387/1901-11-26/ed-1/',
#   'https://www.loc.gov/resource/sn83025308/1892-01-30/ed-1/'],
#  '1870': ['https://www.loc.gov/resource/sn83030272/1906-04-22/ed-1/?sp=36&q=Chinese+Diplomats+Joke+Roller+Skating+Skate+Skates+Craze',
